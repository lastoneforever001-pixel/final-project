# %%
# class object

# %%
# class < class_name>:
#  <nethands>
# obj =<class_name>()

# %%
class A:
    c= False 
print(A.c)
print (not A.c)
A.c=12
print(A.c)
# Out:
# False
# True
# 12

# %%
class C:
    def hello(self):
        print("hello")
obj=C()
obj.hello()
# Out:
# hello
