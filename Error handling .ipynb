# %%
try:
    <operation>
except:
    <operation>
# Out:
#   Cell In[1], line 2
#     <operation>
#     ^
# SyntaxError: invalid syntax

# %%
# zero division error

# %%
a=10
b=0
print(a/b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 a=10
#       2 b=0
# ----> 3 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
# value error

# %%
a=int(input("enter a number :"))
# Out:
# enter a number : dfs
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a=int(input("enter a number :"))
#
# ValueError: invalid literal for int() with base 10: 'dfs'

# %%
# type error
a= "2"
b=2
print (a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 # type error
#       2 a= "2"
#       3 b=2
# ----> 4 print (a+b)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# index error 
# 0,1 insted 10
a= [1,2]
a[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 #
#       2 a= [1,2]
# ----> 3 a[10]
#
# IndexError: list index out of range

# %%
# name error
a=10
z
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # name error
#       2 a=10
# ----> 3 z
#
# NameError: name 'z' is not defined

# %%
# syntax error 
a=10
if a==10
    print("10")
# Out:
#   Cell In[12], line 3
#     if a==10
#             ^
# SyntaxError: expected ':'

# %%
# key error
a={"key":"ram"}
a["326"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 a={"key":"ram"}
# ----> 2 a["326"]
#
# KeyError: '326'

# %%
# identational error
def func():
print("sdf")
# Out:
#   Cell In[16], line 2
#     print("sdf")
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
# attribute error
a=[1,2,3,4,5]
a.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 a=[1,2,3,4,5]
# ----> 2 a.lower()
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
# module not found error
import packaging1234
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 2
#       1 # module not found error
# ----> 2 import packaging1234
#
# ModuleNotFoundError: No module named 'packaging1234'

# %%
#file not found errrrrrrror
open("data.uewruhgxt","r")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 open("data.uewruhgxt","r")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.uewruhgxt'

# %%
try:
    <operation>
except:
    <operation>
# Out:
#   Cell In[25], line 2
#     <operation>
#     ^
# SyntaxError: invalid syntax

# %%
try:
    a=int(input("enter a number :"))
    b=1
    print(a/b)
    
    c=[1,2,3,4]
    print(c[10])

except TypeError:
    print("error cannot add str and intiger")
    
except ZeroDivisionError:
    print("denomitar cannot be zero ")
    
except ValueError:
    print ( "str can't be divided by zero")

except :
    print("something went wrong")

# %%
try:
    a=20
    b=20
    print (a/b)
except:
    print("something went wrong")
finally :
    print("done")
# Out:
# 1.0
# done

# %%
sea born plotly,matplotiib

# %%
import secrets
bruh=secrets.token_hex(1000000)
print(bruh)
# Out:
# ...
