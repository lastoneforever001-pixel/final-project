# %%
from bs4 import BeautifulSoup
from bs4 import MarkupResemblesLocatorWarning
import warnings

warnings.filterwarnings("ignore", category=MarkupResemblesLocatorWarning)
soup = BeautifulSoup("https://www.worldometers.info/coronavirus", 'html.parser')

# %%
import requests
data = requests.get(soup)
print(data)
# Out:
# <Response [200]>

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in C:\Users\user\anaconda3\Lib\site-packages (6.1.3)

# %%
raw_data = BeautifulSoup(data.text,"lxml")

# %%
raw_data.title.text
# Out:
# 'COVID - Coronavirus Statistics - Worldometer'

# %%
table = raw_data.find("table",id="main_table_countries_today")

# %%
tags=table.find_all("tr")

# %%
data=[]
for i in tags :
    row =[x.strip()for x in i.stripped_strings]
    data.append(row)

data[:3]
# Out:
# [['#',
#   'Country,',
#   'Other',
#   'Total',
#   'Cases',
#   'New',
#   'Cases',
#   'Total',
#   'Deaths',
#   'New',
#   'Deaths',
#   'Total',
#   'Recovered',
#   'New',
#   'Recovered',
#   'Active',
#   'Cases',
#   'Serious,',
#   'Critical',
#   'Tot\xa0Cases/',
#   '1M pop',
#   'Deaths/',
#   '1M pop',
#   'Total',
#   'Tests',
#   'Tests/',
#   '1M pop',
#   'Population',
#   'Continent',
#   '1 Case',
#   'every X ppl',
#   '1 Death',
#   'every X ppl',
#   '1 Test',
#   'every X ppl',
#   'New Cases/1M pop',
#   'New Deaths/1M pop',
#   'Active Cases/1M pop'],
#  ['North America',
#   '131,889,132',
#   '1,695,941',
#   '127,665,129',
#   '+350',
#   '2,528,062',
#   '6,095',
#   'North America'],
#  ['Asia',
#   '221,500,265',
#   '1,553,662',
#   '205,673,091',
#   '14,273,512',
#   '14,733',
#   'Asia']]

# %%
import csv
with open ("covid.csv","w",newline="",encoding="utf-8") as file:
    x=csv.writer(file)
    x.writerows(data)

# %%
import pandas as pd
df=pd.read_csv("covid.csv",encoding="latin1")
print(df.shape)
print(df.columns)
df.head()
# Out:
# (247, 38)
# Index(['#', 'Country,', 'Other', 'Total', 'Cases', 'New', 'Cases.1', 'Total.1',
#        'Deaths', 'New.1', 'Deaths.1', 'Total.2', 'Recovered', 'New.2',
#        'Recovered.1', 'Active', 'Cases.2', 'Serious,', 'Critical',
#        'TotÂ Cases/', '1M pop', 'Deaths/', '1M pop.1', 'Total.3', 'Tests',
#        'Tests/', '1M pop.2', 'Population', 'Continent', '1 Case',
#        'every X ppl', '1 Death', 'every X ppl.1', '1 Test', 'every X ppl.2',
#        'New Cases/1M pop', 'New Deaths/1M pop', 'Active Cases/1M pop'],
#       dtype='str')
#                #     Country,      Other        Total       Cases        New  \
# 0  North America  131,889,132  1,695,941  127,665,129        +350  2,528,062
# 1           Asia  221,500,265  1,553,662  205,673,091  14,273,512     14,733
# 2         Europe  253,406,198  2,101,824  248,754,104        +474  2,550,270
# 3  South America   70,200,879  1,367,332   66,683,585   2,149,962      8,953
# 4        Oceania   14,895,771     33,015   14,752,388     110,368         31
#
#              Cases.1        Total.1 Deaths New.1  ... Continent 1 Case  \
# 0              6,095  North America    NaN   NaN  ...       NaN    NaN
# 1               Asia            NaN    NaN   NaN  ...       NaN    NaN
# 2              4,453         Europe    NaN   NaN  ...       NaN    NaN
# 3      South America            NaN    NaN   NaN  ...       NaN    NaN
# 4  Australia/Oceania            NaN    NaN   NaN  ...       NaN    NaN
#
#   every X ppl 1 Death every X ppl.1 1 Test every X ppl.2 New Cases/1M pop  \
# 0         NaN     NaN           NaN    NaN           NaN              NaN
# 1         NaN     NaN           NaN    NaN           NaN              NaN
# 2         NaN     NaN           NaN    NaN           NaN              NaN
# 3         NaN     NaN           NaN    NaN           NaN              NaN
# 4         NaN     NaN           NaN    NaN           NaN              NaN
#
#    New Deaths/1M pop  Active Cases/1M pop
# 0                NaN                  NaN
# 1                NaN                  NaN
# 2                NaN                  NaN
# 3                NaN                  NaN
# 4                NaN                  NaN
#
# [5 rows x 38 columns]

# %%
import pandas as pd
df=pd.read_csv("covid.csv")

# %%
print(df.columns)
# Out:
# Index(['#', 'Country,', 'Other', 'Total', 'Cases', 'New', 'Cases.1', 'Total.1',
#        'Deaths', 'New.1', 'Deaths.1', 'Total.2', 'Recovered', 'New.2',
#        'Recovered.1', 'Active', 'Cases.2', 'Serious,', 'Critical',
#        'Tot Cases/', '1M pop', 'Deaths/', '1M pop.1', 'Total.3', 'Tests',
#        'Tests/', '1M pop.2', 'Population', 'Continent', '1 Case',
#        'every X ppl', '1 Death', 'every X ppl.1', '1 Test', 'every X ppl.2',
#        'New Cases/1M pop', 'New Deaths/1M pop', 'Active Cases/1M pop'],
#       dtype='str')

# %%
country=df[["Country,","Other"]].values.tolist()
total_case=df["Total"].dropna()
total_recovered=df["Active"]

# %%
import plotly .graph_objects as go
fig = go.Figure([go.Bar(x=country[:10],y=new_case[:10])])
fig.show()

# %%
import plotly.graph_objects as go
fig=go.Figure(data=[
    go.Bar(x=country,y=new_case),
    go.Bar(x=country,y=total_recovered)
])
fig.show()
