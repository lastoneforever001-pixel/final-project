# %%
from bs4 import BeautifulSoup
from bs4 import MarkupResemblesLocatorWarning
import warnings

warnings.filterwarnings("ignore", category=MarkupResemblesLocatorWarning)
soup = BeautifulSoup("https://ndrrma.gov.np/en/rasuwa", 'html.parser')

# %%
raw_data = BeautifulSoup(data.text,"lxml")

# %%
raw_data.title.text
# Out:
# 'NDRRMA'

# %%
table = raw_data.find("section",attrs={"aria-labelledby": "rescue-results-heading"})

# %%
import pandas as pd
import requests

api_url="https://ndrrma.gov.np/en/rasuwa"
response = requests.get(api_url)

json_data = response.json()
records = jason_data.get("data",json_data)
df=pd.DataFrame(records)
df.head()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\requests\models.py:1116, in Response.json(self, **kwargs)
#    1115 try:
# -> 1116     return complexjson.loads(self.text, **kwargs)
#    1117 except JSONDecodeError as e:
#    1118     # Catch JSON-related errors and raise as requests.JSONDecodeError
#    1119     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\Lib\json\__init__.py:352, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     349 if (cls is None and object_hook is None and
#     350         parse_int is None and parse_float is None and
#     351         parse_constant is None and object_pairs_hook is None and not kw):
# --> 352     return _default_decoder.decode(s)
#     353 if cls is None:
#
# ...

# %%
table
